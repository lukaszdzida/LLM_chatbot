# %%
# !pip install pytest
# Out:
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/anaconda/envs/azureml_py38/lib/python3.10/site-packages)
# Requirement already satisfied: pytest in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (9.0.1)
# Requirement already satisfied: exceptiongroup>=1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest) (1.3.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest) (2.3.0)
# Requirement already satisfied: packaging>=22 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest) (2.19.1)
# Requirement already satisfied: tomli>=1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from exceptiongroup>=1->pytest) (4.15.0)
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/anaconda/envs/azureml_py38/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/anaconda/envs/azureml_py38/lib/python3.10/site-packages)

# %%
# !pip install ipytest
# Out:
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/anaconda/envs/azureml_py38/lib/python3.10/site-packages)
# Requirement already satisfied: ipytest in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (0.14.2)
# Requirement already satisfied: ipython in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipytest) (8.35.0)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipytest) (25.0)
# Requirement already satisfied: pytest>=5.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipytest) (9.0.1)
# Requirement already satisfied: exceptiongroup>=1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest>=5.4->ipytest) (1.3.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest>=5.4->ipytest) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest>=5.4->ipytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest>=5.4->ipytest) (2.19.1)
# Requirement already satisfied: tomli>=1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest>=5.4->ipytest) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from exceptiongroup>=1->pytest>=5.4->ipytest) (4.15.0)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (0.17.2)
# Requirement already satisfied: matplotlib-inline in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (3.0.50)
# Requirement already satisfied: stack_data in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython->ipytest) (5.14.3)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipytest) (0.2.13)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jedi>=0.16->ipython->ipytest) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack_data->ipython->ipytest) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack_data->ipython->ipytest) (3.0.0)
# Requirement already satisfied: pure-eval in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack_data->ipython->ipytest) (0.2.3)
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/anaconda/envs/azureml_py38/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cudnn-cu12 (/anaconda/envs/azureml_py38/lib/python3.10/site-packages)

# %%
import ipytest
import pytest
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# Load the dataset
iris = load_iris()
X, y = iris.data, iris.target

# Set up the model
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
def test_typical_case():
    input_data = np.array([[4.5, 2.3, 1.3, 0.3]])  # Example input for a flower classification model
    expected_output = 0  # Expected output for typical case (Setosa class index)
    result = model.predict(input_data)[0]
    assert result == expected_output, f"Expected {expected_output}, but got {result}"

# %%
def test_edge_case_extreme_values():
    input_data = np.array([[1000, 1000, 1000, 1000]])  # Extreme values for flower classification
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for extreme inputs
    else:
        assert False, "Expected ValueError for extreme values, but no error was raised"

# %%
def test_error_handling_missing_values():
    input_data = np.array([[None, None, None, None]])  # Missing values in input
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for missing inputs
    else:
        assert False, "Expected ValueError for missing values, but no error was raised"

# %%
# Run tests using ipytest
ipytest.run('-v')
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.10.11, pytest-9.0.1, pluggy-1.6.0 -- /anaconda/envs/azureml_py38/bin/python
# cachedir: .pytest_cache
# rootdir: /mnt/batch/tasks/shared/LS_root/mounts/clusters/lukaszliczy/code/fine-tuning/testing
# plugins: anyio-4.9.0, typeguard-4.3.0
# collecting ... collected 3 items
#
# t_6d469179db3c4e169f819978ca23b61b.py::test_typical_case PASSED                              [ 33%]
# t_6d469179db3c4e169f819978ca23b61b.py::test_edge_case_extreme_values FAILED                  [ 66%]
# t_6d469179db3c4e169f819978ca23b61b.py::test_error_handling_missing_values FAILED             [100%]
#
# ============================================= FAILURES =============================================
# __________________________________ test_edge_case_extreme_values ___________________________________
#
#     def test_edge_case_extreme_values():
#         input_data = np.array([[1000, 1000, 1000, 1000]])  # Extreme values for flower classification
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for extreme inputs
#         else:
# >           assert False, "Expected ValueError for extreme values, but no error was raised"
# E           AssertionError: Expected ValueError for extreme values, but no error was raised
#
# /tmp/ipykernel_4102/1734168487.py:8: AssertionError
# ________________________________ test_error_handling_missing_values ________________________________
#
#     def test_error_handling_missing_values():
#         input_data = np.array([[None, None, None, None]])  # Missing values in input
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for missing inputs
#         else:
# >           assert False, "Expected ValueError for missing values, but no error was raised"
# E           AssertionError: Expected ValueError for missing values, but no error was raised
#
# /tmp/ipykernel_4102/3084191689.py:8: AssertionError
# ===================================== short test summary info ======================================
# FAILED t_6d469179db3c4e169f819978ca23b61b.py::test_edge_case_extreme_values - AssertionError: Expected ValueError for extreme values, but no error was raised
# FAILED t_6d469179db3c4e169f819978ca23b61b.py::test_error_handling_missing_values - AssertionError: Expected ValueError for missing values, but no error was raised
# =================================== 2 failed, 1 passed in 0.08s ====================================
# <ExitCode.TESTS_FAILED: 1>
